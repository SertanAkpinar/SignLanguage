# %%
import os
import cv2
import numpy as np
import mediapipe as mp
import json
import time

# %%
SINGLE_IMAGES_DIR = '../images/single_hand_images'
DOUBLE_IMAGES_DIR = '../images/double_hand_images'
SINGLE_JSON_DIR = '../json/single_hand_json'
DOUBLE_JSON_DIR = '../json/double_hand_json'
single_hand_labels = ['hallo', 'i love u', 'peace'] # 'ich', 'bin', 'S', 'E', 'R', 'T', 'A', 'N']
double_hand_labels = ['bachelor1', 'bachelor2']

# %%
def capture_single_hand_images(IMAGES_DIR, labels, num_images_per_label=50):
    if not os.path.exists(IMAGES_DIR):
        os.makedirs(IMAGES_DIR)

    cap = cv2.VideoCapture(0)

    # Bildaufnahme für Einzelhandzeichen
    for label in labels:
        print(f"Bereit für Einzelhandzeichen: {label}. Drücke 'g', um Bilder aufzunehmen.")
        while True:
            ret, frame = cap.read()
            cv2.imshow('frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('g'):
                # 3 Sekunden Countdown
                for i in range(3, 0, -1):
                    print(f"Capturing in {i} seconds...")
                    time.sleep(1)

                # Aufnahme für die rechte Hand
                label_dir = os.path.join(IMAGES_DIR, label)
                os.makedirs(label_dir, exist_ok=True)
                for i in range(num_images_per_label):
                    ret, frame = cap.read()
                    img_name = f"{label_dir}/{label}_right_{i}.jpg"
                    cv2.imwrite(img_name, frame)
                    print(f"Captured {img_name}")
                    cv2.imshow('frame', frame)
                    cv2.waitKey(100)

                print(f"Fertig mit dem ersten Satz für {label}. Jetzt die andere Hand bereit machen und 'g' drücken, um fortzufahren.")
            
                # Warte, bis der Benutzer bereit ist, den nächsten Satz Bilder aufzunehmen
                while True:
                    if cv2.waitKey(1) & 0xFF == ord('g'):
                        break

                # Aufnahme für die linke Hand
                for i in range(num_images_per_label):
                    ret, frame = cap.read()
                    img_name = f"{label_dir}/{label}_left_{i}.jpg"
                    cv2.imwrite(img_name, frame)
                    print(f"Captured {img_name}")
                    cv2.imshow('frame', frame)
                    cv2.waitKey(100)

                print(f"Fertig mit Einzelhandzeichen: {label}. Drücke 'g' für das nächste Label.")
                break

    cap.release()
    cv2.destroyAllWindows()
    cv2.waitKey(1)

capture_single_hand_images(SINGLE_IMAGES_DIR, single_hand_labels)
# Out:
# Bereit für Einzelhandzeichen: hallo. Drücke 'g', um Bilder aufzunehmen.
# Capturing in 3 seconds...
# Capturing in 2 seconds...
# Capturing in 1 seconds...
# Captured ../images/single_hand_images/hallo/hallo_right_0.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_1.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_2.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_3.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_4.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_5.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_6.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_7.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_8.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_9.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_10.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_11.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_12.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_13.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_14.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_15.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_16.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_17.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_18.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_19.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_20.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_21.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_22.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_23.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_24.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_25.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_26.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_27.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_28.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_29.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_30.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_31.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_32.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_33.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_34.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_35.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_36.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_37.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_38.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_39.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_40.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_41.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_42.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_43.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_44.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_45.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_46.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_47.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_48.jpg
# Captured ../images/single_hand_images/hallo/hallo_right_49.jpg
# Fertig mit dem ersten Satz für hallo. Jetzt die andere Hand bereit machen und 'g' drücken, um fortzufahren.
# Captured ../images/single_hand_images/hallo/hallo_left_0.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_1.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_2.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_3.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_4.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_5.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_6.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_7.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_8.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_9.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_10.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_11.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_12.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_13.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_14.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_15.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_16.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_17.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_18.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_19.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_20.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_21.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_22.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_23.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_24.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_25.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_26.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_27.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_28.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_29.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_30.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_31.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_32.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_33.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_34.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_35.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_36.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_37.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_38.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_39.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_40.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_41.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_42.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_43.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_44.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_45.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_46.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_47.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_48.jpg
# Captured ../images/single_hand_images/hallo/hallo_left_49.jpg
# Fertig mit Einzelhandzeichen: hallo. Drücke 'g' für das nächste Label.
# Bereit für Einzelhandzeichen: i love u. Drücke 'g', um Bilder aufzunehmen.
# Capturing in 3 seconds...
# Capturing in 2 seconds...
# Capturing in 1 seconds...
# Captured ../images/single_hand_images/i love u/i love u_right_0.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_1.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_2.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_3.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_4.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_5.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_6.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_7.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_8.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_9.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_10.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_11.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_12.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_13.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_14.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_15.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_16.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_17.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_18.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_19.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_20.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_21.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_22.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_23.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_24.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_25.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_26.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_27.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_28.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_29.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_30.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_31.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_32.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_33.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_34.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_35.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_36.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_37.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_38.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_39.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_40.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_41.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_42.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_43.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_44.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_45.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_46.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_47.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_48.jpg
# Captured ../images/single_hand_images/i love u/i love u_right_49.jpg
# Fertig mit dem ersten Satz für i love u. Jetzt die andere Hand bereit machen und 'g' drücken, um fortzufahren.
# Captured ../images/single_hand_images/i love u/i love u_left_0.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_1.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_2.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_3.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_4.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_5.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_6.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_7.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_8.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_9.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_10.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_11.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_12.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_13.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_14.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_15.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_16.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_17.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_18.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_19.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_20.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_21.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_22.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_23.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_24.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_25.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_26.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_27.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_28.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_29.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_30.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_31.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_32.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_33.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_34.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_35.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_36.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_37.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_38.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_39.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_40.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_41.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_42.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_43.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_44.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_45.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_46.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_47.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_48.jpg
# Captured ../images/single_hand_images/i love u/i love u_left_49.jpg
# Fertig mit Einzelhandzeichen: i love u. Drücke 'g' für das nächste Label.
# Bereit für Einzelhandzeichen: peace. Drücke 'g', um Bilder aufzunehmen.
# Capturing in 3 seconds...
# Capturing in 2 seconds...
# Capturing in 1 seconds...
# Captured ../images/single_hand_images/peace/peace_right_0.jpg
# Captured ../images/single_hand_images/peace/peace_right_1.jpg
# Captured ../images/single_hand_images/peace/peace_right_2.jpg
# Captured ../images/single_hand_images/peace/peace_right_3.jpg
# Captured ../images/single_hand_images/peace/peace_right_4.jpg
# Captured ../images/single_hand_images/peace/peace_right_5.jpg
# Captured ../images/single_hand_images/peace/peace_right_6.jpg
# Captured ../images/single_hand_images/peace/peace_right_7.jpg
# Captured ../images/single_hand_images/peace/peace_right_8.jpg
# Captured ../images/single_hand_images/peace/peace_right_9.jpg
# Captured ../images/single_hand_images/peace/peace_right_10.jpg
# Captured ../images/single_hand_images/peace/peace_right_11.jpg
# Captured ../images/single_hand_images/peace/peace_right_12.jpg
# Captured ../images/single_hand_images/peace/peace_right_13.jpg
# Captured ../images/single_hand_images/peace/peace_right_14.jpg
# Captured ../images/single_hand_images/peace/peace_right_15.jpg
# Captured ../images/single_hand_images/peace/peace_right_16.jpg
# Captured ../images/single_hand_images/peace/peace_right_17.jpg
# Captured ../images/single_hand_images/peace/peace_right_18.jpg
# Captured ../images/single_hand_images/peace/peace_right_19.jpg
# Captured ../images/single_hand_images/peace/peace_right_20.jpg
# Captured ../images/single_hand_images/peace/peace_right_21.jpg
# Captured ../images/single_hand_images/peace/peace_right_22.jpg
# Captured ../images/single_hand_images/peace/peace_right_23.jpg
# Captured ../images/single_hand_images/peace/peace_right_24.jpg
# Captured ../images/single_hand_images/peace/peace_right_25.jpg
# Captured ../images/single_hand_images/peace/peace_right_26.jpg
# Captured ../images/single_hand_images/peace/peace_right_27.jpg
# Captured ../images/single_hand_images/peace/peace_right_28.jpg
# Captured ../images/single_hand_images/peace/peace_right_29.jpg
# Captured ../images/single_hand_images/peace/peace_right_30.jpg
# Captured ../images/single_hand_images/peace/peace_right_31.jpg
# Captured ../images/single_hand_images/peace/peace_right_32.jpg
# Captured ../images/single_hand_images/peace/peace_right_33.jpg
# Captured ../images/single_hand_images/peace/peace_right_34.jpg
# Captured ../images/single_hand_images/peace/peace_right_35.jpg
# Captured ../images/single_hand_images/peace/peace_right_36.jpg
# Captured ../images/single_hand_images/peace/peace_right_37.jpg
# Captured ../images/single_hand_images/peace/peace_right_38.jpg
# Captured ../images/single_hand_images/peace/peace_right_39.jpg
# Captured ../images/single_hand_images/peace/peace_right_40.jpg
# Captured ../images/single_hand_images/peace/peace_right_41.jpg
# Captured ../images/single_hand_images/peace/peace_right_42.jpg
# Captured ../images/single_hand_images/peace/peace_right_43.jpg
# Captured ../images/single_hand_images/peace/peace_right_44.jpg
# Captured ../images/single_hand_images/peace/peace_right_45.jpg
# Captured ../images/single_hand_images/peace/peace_right_46.jpg
# Captured ../images/single_hand_images/peace/peace_right_47.jpg
# Captured ../images/single_hand_images/peace/peace_right_48.jpg
# Captured ../images/single_hand_images/peace/peace_right_49.jpg
# Fertig mit dem ersten Satz für peace. Jetzt die andere Hand bereit machen und 'g' drücken, um fortzufahren.
# Captured ../images/single_hand_images/peace/peace_left_0.jpg
# Captured ../images/single_hand_images/peace/peace_left_1.jpg
# Captured ../images/single_hand_images/peace/peace_left_2.jpg
# Captured ../images/single_hand_images/peace/peace_left_3.jpg
# Captured ../images/single_hand_images/peace/peace_left_4.jpg
# Captured ../images/single_hand_images/peace/peace_left_5.jpg
# Captured ../images/single_hand_images/peace/peace_left_6.jpg
# Captured ../images/single_hand_images/peace/peace_left_7.jpg
# Captured ../images/single_hand_images/peace/peace_left_8.jpg
# Captured ../images/single_hand_images/peace/peace_left_9.jpg
# Captured ../images/single_hand_images/peace/peace_left_10.jpg
# Captured ../images/single_hand_images/peace/peace_left_11.jpg
# Captured ../images/single_hand_images/peace/peace_left_12.jpg
# Captured ../images/single_hand_images/peace/peace_left_13.jpg
# Captured ../images/single_hand_images/peace/peace_left_14.jpg
# Captured ../images/single_hand_images/peace/peace_left_15.jpg
# Captured ../images/single_hand_images/peace/peace_left_16.jpg
# Captured ../images/single_hand_images/peace/peace_left_17.jpg
# Captured ../images/single_hand_images/peace/peace_left_18.jpg
# Captured ../images/single_hand_images/peace/peace_left_19.jpg
# Captured ../images/single_hand_images/peace/peace_left_20.jpg
# Captured ../images/single_hand_images/peace/peace_left_21.jpg
# Captured ../images/single_hand_images/peace/peace_left_22.jpg
# Captured ../images/single_hand_images/peace/peace_left_23.jpg
# Captured ../images/single_hand_images/peace/peace_left_24.jpg
# Captured ../images/single_hand_images/peace/peace_left_25.jpg
# Captured ../images/single_hand_images/peace/peace_left_26.jpg
# Captured ../images/single_hand_images/peace/peace_left_27.jpg
# Captured ../images/single_hand_images/peace/peace_left_28.jpg
# Captured ../images/single_hand_images/peace/peace_left_29.jpg
# Captured ../images/single_hand_images/peace/peace_left_30.jpg
# Captured ../images/single_hand_images/peace/peace_left_31.jpg
# Captured ../images/single_hand_images/peace/peace_left_32.jpg
# Captured ../images/single_hand_images/peace/peace_left_33.jpg
# Captured ../images/single_hand_images/peace/peace_left_34.jpg
# Captured ../images/single_hand_images/peace/peace_left_35.jpg
# Captured ../images/single_hand_images/peace/peace_left_36.jpg
# Captured ../images/single_hand_images/peace/peace_left_37.jpg
# Captured ../images/single_hand_images/peace/peace_left_38.jpg
# Captured ../images/single_hand_images/peace/peace_left_39.jpg
# Captured ../images/single_hand_images/peace/peace_left_40.jpg
# Captured ../images/single_hand_images/peace/peace_left_41.jpg
# Captured ../images/single_hand_images/peace/peace_left_42.jpg
# Captured ../images/single_hand_images/peace/peace_left_43.jpg
# Captured ../images/single_hand_images/peace/peace_left_44.jpg
# Captured ../images/single_hand_images/peace/peace_left_45.jpg
# Captured ../images/single_hand_images/peace/peace_left_46.jpg
# Captured ../images/single_hand_images/peace/peace_left_47.jpg
# Captured ../images/single_hand_images/peace/peace_left_48.jpg
# Captured ../images/single_hand_images/peace/peace_left_49.jpg
# Fertig mit Einzelhandzeichen: peace. Drücke 'g' für das nächste Label.

# %%
def capture_double_hand_images(IMAGES_DIR, labels, num_images_per_label=50):
    if not os.path.exists(IMAGES_DIR):
        os.makedirs(IMAGES_DIR)

    cap = cv2.VideoCapture(0)

    # Bildaufnahme für Doppelhandzeichen
    for label in labels:
        print(f"Bereit für Doppelhandzeichen: {label}. Drücke 'g', um Bilder aufzunehmen.")
        while True:
            ret, frame = cap.read()
            cv2.imshow('frame', frame)
            if cv2.waitKey(1) & 0xFF == ord('g'):
                # 3 Sekunden Countdown
                for i in range(3, 0, -1):
                    print(f"Capturing in {i} seconds...")
                    time.sleep(1)

                # Aufnahme für Doppelhand
                label_dir = os.path.join(IMAGES_DIR, label)
                os.makedirs(label_dir, exist_ok=True)
                for i in range(num_images_per_label):
                    ret, frame = cap.read()
                    img_name = f"{label_dir}/{label}_{i}.jpg"  # Nur ein Label für beide Hände
                    cv2.imwrite(img_name, frame)
                    print(f"Captured {img_name}")
                    cv2.imshow('frame', frame)
                    cv2.waitKey(100)

                print(f"Fertig mit Doppelhandzeichen: {label}. Drücke 'g' für das nächste Label.")
                break

    cap.release()
    cv2.destroyAllWindows()
    cv2.waitKey(1)

capture_double_hand_images(DOUBLE_IMAGES_DIR, double_hand_labels)
# Out:
# Bereit für Doppelhandzeichen: bachelor1. Drücke 'g', um Bilder aufzunehmen.
# Capturing in 3 seconds...
# Capturing in 2 seconds...
# Capturing in 1 seconds...
# Captured ../images/double_hand_images/bachelor1/bachelor1_0.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_1.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_2.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_3.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_4.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_5.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_6.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_7.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_8.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_9.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_10.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_11.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_12.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_13.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_14.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_15.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_16.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_17.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_18.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_19.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_20.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_21.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_22.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_23.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_24.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_25.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_26.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_27.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_28.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_29.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_30.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_31.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_32.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_33.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_34.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_35.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_36.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_37.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_38.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_39.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_40.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_41.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_42.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_43.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_44.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_45.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_46.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_47.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_48.jpg
# Captured ../images/double_hand_images/bachelor1/bachelor1_49.jpg
# Fertig mit Doppelhandzeichen: bachelor1. Drücke 'g' für das nächste Label.
# Bereit für Doppelhandzeichen: bachelor2. Drücke 'g', um Bilder aufzunehmen.
# Capturing in 3 seconds...
# Capturing in 2 seconds...
# Capturing in 1 seconds...
# Captured ../images/double_hand_images/bachelor2/bachelor2_0.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_1.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_2.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_3.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_4.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_5.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_6.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_7.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_8.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_9.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_10.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_11.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_12.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_13.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_14.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_15.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_16.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_17.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_18.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_19.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_20.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_21.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_22.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_23.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_24.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_25.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_26.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_27.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_28.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_29.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_30.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_31.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_32.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_33.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_34.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_35.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_36.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_37.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_38.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_39.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_40.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_41.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_42.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_43.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_44.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_45.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_46.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_47.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_48.jpg
# Captured ../images/double_hand_images/bachelor2/bachelor2_49.jpg
# Fertig mit Doppelhandzeichen: bachelor2. Drücke 'g' für das nächste Label.

# %%
def augment_image(img):
    rows, cols, _ = img.shape

    # Zufällige Drehung
    angle = np.random.uniform(-30, 30)
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
    img = cv2.warpAffine(img, M, (cols, rows))

    # Zufällige Skalierung
    scale = np.random.uniform(0.7, 1.3)
    img = cv2.resize(img, None, fx=scale, fy=scale)

    # Zufällige Verschiebung
    max_dx = 0.1 * cols
    max_dy = 0.1 * rows
    dx = np.random.uniform(-max_dx, max_dx)
    dy = np.random.uniform(-max_dy, max_dy)
    M = np.float32([[1, 0, dx], [0, 1, dy]])
    img = cv2.warpAffine(img, M, (cols, rows))

    # Zufällige Spiegelung
    if np.random.rand() < 0.5:
        img = cv2.flip(img, 1)

    return img

def augment_and_save_images(img_dir, num_augmented_images):
    for img_name in os.listdir(img_dir):
        img_path = os.path.join(img_dir, img_name)
        if os.path.isfile(img_path):
            img = cv2.imread(img_path)
            
            # Füge augmentierte Bilder hinzu
            for i in range(num_augmented_images):
                augmented_img = augment_image(img)
                
                # Erstelle neuen Dateinamen für augmentierte Bilder
                augmented_img_name = f"{img_name.split('.')[0]}_aug_{i}.jpg"
                augmented_img_path = os.path.join(img_dir, augmented_img_name)
                
                # Speichere das augmentierte Bild
                cv2.imwrite(augmented_img_path, augmented_img)
                print(f"Augmentiertes Bild gespeichert: {augmented_img_path}")

# Augmentiere Bilder für jedes Label in single_hand_labels
for label in single_hand_labels:
    label_path = os.path.join(SINGLE_IMAGES_DIR, label)
    if os.path.isdir(label_path):
        augment_and_save_images(label_path, num_augmented_images=5)

# Augmentiere Bilder für jedes Label in double_hand_labels
for label in double_hand_labels:
    label_path = os.path.join(DOUBLE_IMAGES_DIR, label)
    if os.path.isdir(label_path):
        augment_and_save_images(label_path, num_augmented_images=5)
# Out:
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_45_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_45_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_45_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_45_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_45_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_28_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_28_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_28_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_28_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_28_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_14_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_14_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_14_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_14_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_14_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_15_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_15_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_15_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_15_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_15_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_29_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_29_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_29_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_29_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_29_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_44_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_44_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_44_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_44_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_44_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_46_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_46_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_46_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_46_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_46_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_17_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_17_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_17_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_17_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_17_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_16_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_16_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_16_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_16_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_16_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_47_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_47_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_47_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_47_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_47_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_43_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_43_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_43_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_43_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_43_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_12_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_12_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_12_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_12_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_12_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_13_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_13_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_13_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_13_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_13_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_42_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_42_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_42_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_42_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_42_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_40_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_40_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_40_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_40_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_40_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_9_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_9_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_9_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_9_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_9_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_11_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_11_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_11_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_11_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_11_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_39_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_39_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_39_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_39_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_39_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_38_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_38_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_38_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_38_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_38_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_10_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_10_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_10_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_10_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_10_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_8_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_8_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_8_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_8_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_8_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_41_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_41_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_41_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_41_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_41_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_32_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_32_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_32_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_32_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_32_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_26_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_26_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_26_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_26_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_26_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_2_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_2_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_2_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_2_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_2_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_3_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_3_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_3_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_3_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_3_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_27_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_27_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_27_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_27_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_27_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_33_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_33_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_33_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_33_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_33_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_25_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_25_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_25_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_25_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_25_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_31_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_31_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_31_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_31_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_31_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_19_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_19_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_19_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_19_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_19_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_1_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_1_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_1_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_1_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_1_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_48_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_48_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_48_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_48_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_48_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_49_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_49_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_49_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_49_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_49_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_0_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_0_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_0_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_0_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_0_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_18_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_18_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_18_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_18_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_18_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_30_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_30_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_30_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_30_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_30_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_24_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_24_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_24_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_24_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_24_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_20_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_20_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_20_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_20_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_20_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_34_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_34_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_34_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_34_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_34_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_4_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_4_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_4_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_4_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_4_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_5_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_5_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_5_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_5_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_5_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_35_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_35_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_35_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_35_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_35_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_21_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_21_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_21_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_21_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_21_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_37_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_37_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_37_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_37_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_37_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_23_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_23_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_23_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_23_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_23_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_7_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_7_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_7_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_7_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_7_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_6_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_6_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_6_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_6_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_6_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_22_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_22_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_22_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_22_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_22_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_36_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_36_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_36_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_36_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_36_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_13_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_13_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_13_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_13_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_13_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_42_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_42_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_42_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_42_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_42_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_43_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_43_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_43_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_43_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_43_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_12_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_12_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_12_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_12_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_12_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_10_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_10_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_10_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_10_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_10_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_38_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_38_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_38_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_38_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_38_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_8_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_8_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_8_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_8_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_8_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_41_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_41_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_41_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_41_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_41_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_40_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_40_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_40_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_40_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_40_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_9_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_9_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_9_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_9_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_9_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_39_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_39_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_39_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_39_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_39_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_11_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_11_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_11_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_11_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_11_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_29_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_29_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_29_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_29_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_29_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_15_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_15_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_15_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_15_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_15_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_44_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_44_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_44_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_44_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_44_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_45_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_45_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_45_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_45_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_45_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_14_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_14_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_14_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_14_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_14_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_28_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_28_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_28_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_28_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_28_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_16_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_16_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_16_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_16_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_16_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_47_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_47_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_47_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_47_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_47_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_46_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_46_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_46_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_46_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_46_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_17_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_17_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_17_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_17_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_17_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_5_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_5_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_5_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_5_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_5_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_21_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_21_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_21_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_21_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_21_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_35_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_35_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_35_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_35_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_35_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_34_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_34_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_34_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_34_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_34_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_20_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_20_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_20_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_20_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_20_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_4_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_4_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_4_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_4_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_4_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_6_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_6_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_6_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_6_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_6_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_36_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_36_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_36_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_36_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_36_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_22_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_22_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_22_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_22_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_22_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_23_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_23_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_23_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_23_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_23_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_37_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_37_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_37_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_37_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_37_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_7_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_7_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_7_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_7_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_7_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_3_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_3_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_3_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_3_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_3_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_33_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_33_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_33_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_33_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_33_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_27_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_27_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_27_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_27_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_27_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_26_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_26_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_26_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_26_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_26_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_32_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_32_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_32_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_32_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_32_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_2_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_2_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_2_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_2_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_2_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_49_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_49_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_49_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_49_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_49_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_0_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_0_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_0_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_0_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_0_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_24_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_24_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_24_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_24_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_24_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_30_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_30_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_30_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_30_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_30_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_18_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_18_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_18_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_18_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_18_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_19_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_19_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_19_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_19_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_19_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_31_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_31_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_31_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_31_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_31_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_25_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_25_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_25_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_25_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_25_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_1_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_1_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_1_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_1_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_left_1_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_48_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_48_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_48_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_48_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/hallo/hallo_right_48_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_36_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_36_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_36_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_36_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_36_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_22_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_22_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_22_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_22_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_22_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_44_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_44_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_44_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_44_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_44_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_45_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_45_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_45_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_45_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_right_45_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_23_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_23_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_23_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/single_hand_images/i love u/i love u_left_23_aug_3.jpg
# ...
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_27_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_27_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_27_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_27_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_27_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_33_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_33_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_33_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_33_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_33_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_32_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_32_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_32_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_32_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_32_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_26_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_26_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_26_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_26_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_26_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_41_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_41_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_41_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_41_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_41_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_40_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_40_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_40_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_40_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_40_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_42_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_42_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_42_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_42_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_42_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_43_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_43_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_43_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_43_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_43_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_47_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_47_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_47_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_47_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_47_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_46_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_46_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_46_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_46_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_46_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_44_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_44_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_44_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_44_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_44_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_45_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_45_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_45_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_45_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_45_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_48_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_48_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_48_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_48_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_48_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_49_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_49_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_49_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_49_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_49_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_17_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_17_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_17_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_17_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_17_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_3_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_3_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_3_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_3_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_3_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_2_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_2_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_2_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_2_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_2_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_16_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_16_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_16_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_16_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_16_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_28_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_28_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_28_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_28_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_28_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_14_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_14_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_14_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_14_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_14_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_0_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_0_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_0_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_0_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_0_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_1_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_1_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_1_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_1_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_1_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_15_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_15_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_15_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_15_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_15_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_29_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_29_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_29_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_29_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_29_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_11_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_11_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_11_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_11_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_11_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_39_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_39_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_39_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_39_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_39_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_5_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_5_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_5_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_5_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_5_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_4_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_4_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_4_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_4_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_4_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_38_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_38_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_38_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_38_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_38_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_10_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_10_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_10_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_10_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_10_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_12_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_12_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_12_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_12_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_12_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_6_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_6_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_6_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_6_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_6_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_7_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_7_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_7_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_7_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_7_aug_4.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_13_aug_0.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_13_aug_1.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_13_aug_2.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_13_aug_3.jpg
# Augmentiertes Bild gespeichert: ../images/double_hand_images/bachelor2/bachelor2_13_aug_4.jpg

# %%
mp_hands = mp.solutions.hands
mp_pose = mp.solutions.pose
hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3)

def save_single_hand_landmarks_to_json(IMAGES_DIR, json_path, labels):
    if not os.path.exists(IMAGES_DIR):
        print(f"Das Verzeichnis {IMAGES_DIR} existiert nicht.")
        return

    # Stelle sicher, dass das Verzeichnis für die JSON-Datei existiert
    json_dir = os.path.dirname(json_path)
    if not os.path.exists(json_dir):
        os.makedirs(json_dir)

    data = []

    # Verarbeite Einzelhandzeichen
    for label in labels:
        label_dir = os.path.join(IMAGES_DIR, label)
        if os.path.isdir(label_dir):
            for img_name in os.listdir(label_dir):
                img_path = os.path.join(label_dir, img_name)
                img = cv2.imread(img_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # Pose- und Handlandmarks verarbeiten
                pose_results = pose.process(img_rgb)
                hand_results = hands.process(img_rgb)

                # Initialisiere ein Array für alle Landmarks (63 Hand + 9 Pose = 72 Einträge)
                combined_landmarks = []

                # Extrahiere Pose-Landmarks (z.B. LEFT_SHOULDER, RIGHT_SHOULDER, NOSE)
                if pose_results.pose_landmarks:
                    pose_landmarks = ["LEFT_SHOULDER", "RIGHT_SHOULDER", "NOSE"]
                    for name in pose_landmarks:
                        landmark = getattr(mp_pose.PoseLandmark, name)
                        coord = pose_results.pose_landmarks.landmark[landmark]
                        combined_landmarks.extend([coord.x, coord.y, coord.z])
                else:
                    # Füge leere Pose-Landmarks hinzu, falls keine Pose erkannt wurde
                    combined_landmarks.extend([0, 0, 0] * 3)

                # Extrahiere Handlandmarks
                if hand_results.multi_hand_landmarks:
                    for hand_landmarks in hand_results.multi_hand_landmarks:
                        for lm in hand_landmarks.landmark:
                            combined_landmarks.extend([lm.x, lm.y, lm.z])
                        break  # Nur eine Hand pro Einzelhandzeichen nehmen
                else:
                    # Füge leere Handlandmarks hinzu, falls keine Hand erkannt wurde
                    combined_landmarks.extend([0, 0, 0] * 21)

                # Datensatz mit allen Landmarks und Label speichern
                data.append({
                    'label': label,
                    'landmarks': combined_landmarks
                })

    # JSON-Datei erstellen und speichern
    with open(json_path, 'w') as f:
        json.dump({'data': data}, f)

# Definiere den Speicherpfad und rufe die Funktion auf
single_json_path = os.path.join(SINGLE_JSON_DIR, 'single_hand_pose_landmarks_data.json')
save_single_hand_landmarks_to_json(SINGLE_IMAGES_DIR, single_json_path, single_hand_labels)

print("Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.")
# Out:
# I0000 00:00:1731254308.522495 1617864 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# I0000 00:00:1731254308.551498 1617864 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# W0000 00:00:1731254308.683446 1629664 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254308.749821 1629664 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254309.208540 1629666 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254309.254927 1629666 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /opt/anaconda3/envs/pytorch/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.

# %%
mp_hands = mp.solutions.hands
mp_pose = mp.solutions.pose
hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3)

def save_double_hand_landmarks_to_json(IMAGES_DIR, json_path, labels):
    if not os.path.exists(IMAGES_DIR):
        print(f"Das Verzeichnis {IMAGES_DIR} existiert nicht.")
        return

    # Stelle sicher, dass das Verzeichnis für die JSON-Datei existiert
    json_dir = os.path.dirname(json_path)
    if not os.path.exists(json_dir):
        os.makedirs(json_dir)

    data = []

    # Verarbeite Doppelhandzeichen
    for label in labels:
        label_dir = os.path.join(IMAGES_DIR, label)
        if os.path.isdir(label_dir):
            for img_name in os.listdir(label_dir):
                img_path = os.path.join(label_dir, img_name)
                img = cv2.imread(img_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # Pose- und Handlandmarks verarbeiten
                pose_results = pose.process(img_rgb)
                hand_results = hands.process(img_rgb)

                # Initialisiere ein Array für alle Landmarks
                combined_landmarks = []

                # Extrahiere Handlandmarks für beide Hände
                left_hand_landmarks = [0, 0, 0] * 21
                right_hand_landmarks = [0, 0, 0] * 21
                if hand_results.multi_hand_landmarks:
                    for hand_landmarks, handedness in zip(hand_results.multi_hand_landmarks, hand_results.multi_handedness):
                        hand_label = handedness.classification[0].label
                        if hand_label == 'Left':
                            left_hand_landmarks = [coord for lm in hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
                        else:
                            right_hand_landmarks = [coord for lm in hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]

                combined_landmarks.extend(left_hand_landmarks)
                combined_landmarks.extend(right_hand_landmarks)

                # Extrahiere Pose-Landmarks (z.B. LEFT_SHOULDER, RIGHT_SHOULDER, NOSE)
                pose_landmarks = ["LEFT_SHOULDER", "RIGHT_SHOULDER", "NOSE"]
                if pose_results.pose_landmarks:
                    for name in pose_landmarks:
                        landmark = getattr(mp_pose.PoseLandmark, name)
                        coord = pose_results.pose_landmarks.landmark[landmark]
                        combined_landmarks.extend([coord.x, coord.y, coord.z])
                else:
                    # Füge leere Pose-Landmarks hinzu, falls keine Pose erkannt wurde
                    combined_landmarks.extend([0, 0, 0] * 3)

                # Datensatz mit allen Landmarks und Label speichern
                data.append({
                    'label': label,
                    'landmarks': combined_landmarks
                })

    # JSON-Datei erstellen und speichern
    with open(json_path, 'w') as f:
        json.dump({'data': data}, f)

# Definiere den Speicherpfad und rufe die Funktion auf
double_json_path = os.path.join(DOUBLE_JSON_DIR, 'double_hand_pose_landmarks_data.json')
save_double_hand_landmarks_to_json(DOUBLE_IMAGES_DIR, double_json_path, double_hand_labels)

print("Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.")
# Out:
# I0000 00:00:1731254508.732396 1617864 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# I0000 00:00:1731254508.764938 1617864 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# W0000 00:00:1731254508.832218 1630365 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254508.878998 1630365 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254509.171310 1630371 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731254509.288729 1630371 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.

# %%
#BEIDES

import os
import cv2
import numpy as np
import mediapipe as mp
import json

# Initialisiere Mediapipe für Hände und Pose
mp_hands = mp.solutions.hands
mp_pose = mp.solutions.pose
hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.3)
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.3)

def save_landmarks_to_json(IMAGES_DIR, json_path, labels, is_double_hand=False):
    if not os.path.exists(IMAGES_DIR):
        print(f"Das Verzeichnis {IMAGES_DIR} existiert nicht.")
        return

    # Stelle sicher, dass das Verzeichnis für die JSON-Datei existiert
    json_dir = os.path.dirname(json_path)
    if not os.path.exists(json_dir):
        os.makedirs(json_dir)

    data = []

    # Verarbeite die Handzeichen
    for label in labels:
        label_dir = os.path.join(IMAGES_DIR, label)
        if os.path.isdir(label_dir):
            for img_name in os.listdir(label_dir):
                img_path = os.path.join(label_dir, img_name)
                img = cv2.imread(img_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # Pose- und Handlandmarks verarbeiten
                pose_results = pose.process(img_rgb)
                hand_results = hands.process(img_rgb)

                # Initialisiere ein Array für alle Landmarks
                combined_landmarks = []

                # Extrahiere Handlandmarks für beide Hände
                left_hand_landmarks = [0, 0, 0] * 21
                right_hand_landmarks = [0, 0, 0] * 21
                if hand_results.multi_hand_landmarks:
                    for hand_landmarks, handedness in zip(hand_results.multi_hand_landmarks, hand_results.multi_handedness):
                        hand_label = handedness.classification[0].label
                        if hand_label == 'Left':
                            left_hand_landmarks = [coord for lm in hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]
                        else:
                            right_hand_landmarks = [coord for lm in hand_landmarks.landmark for coord in (lm.x, lm.y, lm.z)]

                combined_landmarks.extend(left_hand_landmarks)
                combined_landmarks.extend(right_hand_landmarks)

                # Extrahiere Pose-Landmarks (z.B. LEFT_SHOULDER, RIGHT_SHOULDER, NOSE)
                pose_landmarks = ["LEFT_SHOULDER", "RIGHT_SHOULDER", "NOSE"]
                if pose_results.pose_landmarks:
                    for name in pose_landmarks:
                        landmark = getattr(mp_pose.PoseLandmark, name)
                        coord = pose_results.pose_landmarks.landmark[landmark]
                        combined_landmarks.extend([coord.x, coord.y, coord.z])
                else:
                    # Füge leere Pose-Landmarks hinzu, falls keine Pose erkannt wurde
                    combined_landmarks.extend([0, 0, 0] * 3)

                # Datensatz mit allen Landmarks und Label speichern
                data.append({
                    'label': label,
                    'landmarks': combined_landmarks
                })

    # JSON-Datei erstellen und speichern
    with open(json_path, 'w') as f:
        json.dump({'data': data}, f)

# Definiere den Speicherpfad und rufe die Funktion auf
SINGLE_IMAGES_DIR = '../images/single_hand_images'
DOUBLE_IMAGES_DIR = '../images/double_hand_images'
JSON_DIR = '../json'
single_hand_labels = ['hallo', 'ich', 'bin', 'S', 'E', 'R', 'T', 'A', 'N']
double_hand_labels = ['bachelor1', 'bachelor2']

single_json_path = os.path.join(JSON_DIR, 'single_hand_pose_landmarks_data.json')
double_json_path = os.path.join(JSON_DIR, 'double_hand_pose_landmarks_data.json')

save_landmarks_to_json(SINGLE_IMAGES_DIR, single_json_path, single_hand_labels)
save_landmarks_to_json(DOUBLE_IMAGES_DIR, double_json_path, double_hand_labels, is_double_hand=True)

print("Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.")
# Out:
# I0000 00:00:1731590236.469894   62862 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# W0000 00:00:1731590236.505012   65186 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# I0000 00:00:1731590236.507616   62862 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-18.8.16), renderer: Intel(R) Iris(TM) Graphics 6100
# W0000 00:00:1731590236.591557   65188 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731590236.996352   65190 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1731590237.082789   65190 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Hand- und Pose-Landmarks erfolgreich in einem Array gespeichert.
